# %%
import pandas as pd

# %%
netflix_originals = pd.read_csv('netflix_originals.csv')
netflix_titles = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# ## Análisis Netflix Original.

# %%
netflix_originals = netflix_originals.loc[:, ~netflix_originals.columns.str.contains('^Unnamed')]

# %%
pd.set_option("display.max_columns", None)

# %%
netflix_originals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       513 non-null    object
#  1   Genre       513 non-null    object
#  2   Premiere    513 non-null    object
#  3   Runtime     513 non-null    int64
#  4   IMDB Score  513 non-null    float64
#  5   Language    513 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 24.2+ KB

# %%
# Reemplazar posibles errores en las fechas (por ejemplo, punto por coma)
netflix_originals['Premiere'] = netflix_originals['Premiere'].str.replace(r"\.", ",", regex=True)

# Intentar convertir la columna 'Premiere' a datetime
try:
    netflix_originals['Premiere'] = pd.to_datetime(netflix_originals['Premiere'], format='mixed')
    print("Columna 'Premiere' convertida exitosamente a datetime.")
except Exception as e:
    print(f"Error al convertir 'Premiere': {e}")
# Out:
# Columna 'Premiere' convertida exitosamente a datetime.

# %%
print(netflix_originals['Premiere'].head())
# Out:
# 0   2019-08-05
# 1   2020-08-21
# 2   2019-12-26
# 3   2018-01-19
# 4   2020-10-30
# Name: Premiere, dtype: datetime64[ns]

# %%
netflix_originals.describe()
# Out:
#           Runtime  IMDB Score
# count  513.000000  513.000000
# mean    94.674464    6.210916
# std     26.648121    0.968850
# min      4.000000    2.500000
# 25%     87.000000    5.600000
# 50%     97.000000    6.300000
# 75%    108.000000    6.900000
# max    209.000000    9.000000

# %%
netflix_originals.isnull().sum()
# Out:
# Title         0
# Genre         0
# Premiere      0
# Runtime       0
# IMDB Score    0
# Language      0
# dtype: int64

# %%
netflix_originals.nunique()
# Out:
# Title         513
# Genre         106
# Premiere      350
# Runtime       113
# IMDB Score     52
# Language       37
# dtype: int64

# %%
netflix_originals.dtypes
# Out:
# Title          object
# Genre          object
# Premiere       object
# Runtime         int64
# IMDB Score    float64
# Language       object
# dtype: object

# %%
print(netflix_originals['Title'].head(10))
# Out:
# 0                    Enter the Anime
# 1                        Dark Forces
# 2                            The App
# 3                     The Open House
# 4                        Kaali Khuhi
# 5                              Drive
# 6                  Leyla Everlasting
# 7    The Last Days of American Crime
# 8                            Paradox
# 9                 Sardar Ka Grandson
# Name: Title, dtype: object

# %%
non = netflix_originals.select_dtypes(include='number')
non
# Out:
#      Runtime  IMDB Score
# 0         58         2.5
# 1         81         2.6
# 2         79         2.6
# 3         94         3.2
# 4         90         3.4
# ..       ...         ...
# 508      114         8.3
# 509       51         8.3
# 510       91         8.4
# 511      153         8.5
# 512       83         9.0
#
# [513 rows x 2 columns]

# %%
non.corr()
# Out:
#              Runtime  IMDB Score
# Runtime     1.000000   -0.055775
# IMDB Score -0.055775    1.000000

# %%
high_score = netflix_originals.loc[netflix_originals['IMDB Score'].idxmax()]
high_score
# Out:
# Title         David Attenborough: A Life on Our Planet
# Genre                                      Documentary
# Premiere                           2020-10-04 00:00:00
# Runtime                                             83
# IMDB Score                                         9.0
# Language                                       English
# Name: 512, dtype: object

# %%
most_common_language = netflix_originals['Language'].value_counts().idxmax()
language_count = netflix_originals['Language'].value_counts().max()
print(f"la lengua más representada es {most_common_language} con {language_count} títulos")
# Out:
# la lengua más representada es English con 352 títulos

# %%
top_5_titles = netflix_originals.nlargest(5, 'IMDB Score')[['Title', 'IMDB Score']]
print("Los cinco títulos más puntuados:")
print(top_5_titles)
# Out:
# Los cinco títulos más puntuados:
#                                            Title  IMDB Score
# 512     David Attenborough: A Life on Our Planet         9.0
# 511                      Springsteen on Broadway         8.5
# 510  Winter on Fire: Ukraine's Fight for Freedom         8.4
# 508                       Cuba and the Cameraman         8.3
# 509                       Dancing with the Birds         8.3

# %%
top_5_languages = netflix_originals['Language'].value_counts().head(5)
print("\nLas cinco lenguas más representadas:")
print(top_5_languages)
# Out:
# Las cinco lenguas más representadas:
# Language
# English    352
# Hindi       28
# Spanish     26
# French      18
# Italian     14
# Name: count, dtype: int64

# %% [markdown]
# ## Conclusión de Netflix_Originals
# - La única consistencia en los datos fue encontrada en la columna premiere.
# - No se encontraron nulos ni duplicados.
# - Es un dataframe que consiste en 513 rows × 6 columns
# - Tenemos datos de tipo object y de tipo numerico (int y float)

# %% [markdown]
# # Análisis netflix_titles

# %% [markdown]
# ### conclusiones
# - hay valores nulos significativos en varias columnas pero se van a ignorar.
# - es un dataframe de 8807 filas x 12 columnas
# - hay duplicados

# %%
netflix_titles = netflix_titles.loc[:, ~netflix_titles.columns.str.contains('^Unnamed')]
netflix_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      3994 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
print(netflix_originals['Title'].sample(10))
# Out:
# 193          Come Sunday
# 488    The Bleeding Edge
# 319              Bulbbul
# 315            Tigertail
# 417     Grass Is Greener
# 271              Birders
# 58       Coffee & Kareem
# 284      Take Your Pills
# 246                Benji
# 435         Ladies First
# Name: Title, dtype: object

# %%
print(netflix_titles['title'].sample(10))
# Out:
# 928            Best of the Best
# 2568    Hangar 1: The UFO Files
# 5047    The Cloverfield Paradox
# 4378            The Pixar Story
# 4509                     Soorma
# 5148                     Voyeur
# 6935              Hart of Dixie
# 804              Population 436
# 1199                    Savages
# 1911               Human Nature
# Name: title, dtype: object

# %%
# Identificar títulos de netflix_originals que no se encontraron en netflix_titles
no_match = netflix_originals[~netflix_originals['Title'].isin(netflix_titles['title'])]
print(f"Títulos no encontrados en netflix_titles: {no_match.shape[0]}")
print(no_match.head())
# Out:
# Títulos no encontrados en netflix_titles: 0
# Empty DataFrame
# Columns: [Title, Genre, Premiere, Runtime, IMDB Score, Language]
# Index: []

# %%
netflix_titles.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration        4813
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# - las columnas que más nulos tienen son director y duración

# %%
netflix_titles.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         185
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# - hay descripciones con duplicados

# %%
netflix_titles.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
netflix_titles.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# # Unión de base de datos

# %% [markdown]
# - Se hace un LEFT JOIN para ver qué titulos en el catálogo general (netflix_titles) no son originales de Nertflix.

# %%
netflix_originals.rename(columns={'Title': 'title'}, inplace=True)
merged_data = pd.merge(netflix_titles, netflix_originals, how='left', on='title')

# %%
merged_data.sample(4)
# Out:
#       Unnamed: 0 show_id     type                                      title  \
# 1577        1577   s1578    Movie  emicida: amarelo - it’s all for yesterday
# 2680        2680   s2681    Movie                     puerto ricans in paris
# 5953        5953   s5954    Movie                     joseph: king of dreams
# 2659        2659   s2660  TV Show                     middleditch & schwartz
#
#                            director  \
# 1577                            NaN
# 2680                    Ian Edelman
# 5953  Rob LaDuca, Robert C. Ramirez
# 2659                    Ryan Polito
#
#                                                    cast  \
# 1577                                            Emicida
# 2680  Luis Guzmán, Edgar Garcia, Alice Taglioni, Ros...
# 5953  Ben Affleck, Mark Hamill, Richard Herd, Mauree...
# 2659                   Thomas Middleditch, Ben Schwartz
#
#                                     country          date_added  release_year  \
# ...

# %%
merged_data.isnull().sum()
# Out:
# Unnamed: 0         0
# show_id            0
# type               0
# Title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration        4813
# listed_in          0
# description        0
# Genre           8294
# Premiere        8294
# Runtime         8294
# IMDB Score      8294
# Language        8294
# dtype: int64

# %% [markdown]
# # Filtrado de datos.

# %%
#1. 

merged_data.loc[merged_data['type'] == 'Movie']
# Out:
#       Unnamed: 0 show_id   type                             title  \
# 0              0      s1  Movie              dick johnson is dead
# 6              6      s7  Movie  my little pony: a new generation
# 7              7      s8  Movie                           sankofa
# 9              9     s10  Movie                      the starling
# 12            12     s13  Movie                      je suis karl
# ...          ...     ...    ...                               ...
# 8801        8801   s8802  Movie                           zinzana
# 8802        8802   s8803  Movie                            zodiac
# 8804        8804   s8805  Movie                        zombieland
# 8805        8805   s8806  Movie                              zoom
# 8806        8806   s8807  Movie                            zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...

# %%
#2 solo titutlos y duracion de todos los contenidos que sean tipo tv show 
tv_shows = merged_data.loc[merged_data['type'] == "TV Show", ['title', 'duration']]
tv_shows
# Out:
#                       title   duration
# 1             blood & water  2 Seasons
# 2                 ganglands        NaN
# 3     jailbirds new orleans        NaN
# 4              kota factory  2 Seasons
# 5             midnight mass        NaN
# ...                     ...        ...
# 8795        yu-gi-oh! arc-v  2 Seasons
# 8796             yunus emre  2 Seasons
# 8797              zak storm        NaN
# 8800     zindagi gulzar hai        NaN
# 8803            zombie dumb  2 Seasons
#
# [2676 rows x 2 columns]

# %%
us_titles = merged_data.loc[merged_data['country'] == "United States"]
us_titles
# Out:
#       Unnamed: 0 show_id     type                 title         director  \
# 0              0      s1    Movie  dick johnson is dead  Kirsten Johnson
# 9              9     s10    Movie          the starling   Theodore Melfi
# 15            15     s16  TV Show     dear white people              NaN
# 27            27     s28    Movie             grown ups     Dennis Dugan
# 28            28     s29    Movie            dark skies    Scott Stewart
# ...          ...     ...      ...                   ...              ...
# 8791        8791   s8792    Movie           young adult    Jason Reitman
# 8793        8793   s8794    Movie  yours, mine and ours     Raja Gosnell
# 8802        8802   s8803    Movie                zodiac    David Fincher
# 8804        8804   s8805    Movie            zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                  zoom     Peter Hewitt
#
#                                                    cast        country  \
# ...

# %%
merged_data = merged_data.loc[:, ~merged_data.columns.str.contains('^Unnamed')]

# %%
prod2018 = merged_data.loc[merged_data['release_year'] == 2018, ['title', 'listed_in']]
prod2018
# Out:
#                                                   title  \
# 21                               resurrection: ertugrul
# 37                                          angry birds
# 73                                         king of boys
# 94                                            show dogs
# 96    if i leave here tomorrow: a film about lynyrd ...
# ...                                                 ...
# 8732                                      white chamber
# 8743                                           wildlife
# 8774                                          يوم الدين
# 8775                                    yeh meri family
# 8803                                        zombie dumb
#
#                                               listed_in
# 21    International TV Shows, TV Action & Adventure,...
# 37                                Kids' TV, TV Comedies
# 73                         Dramas, International Movies
# 94                   Children & Family Movies, Comedies
# ...

# %%
sin_director = merged_data.loc[merged_data['director'].isna(), ['title']]
sin_director
# Out:
#                                     title
# 1                           blood & water
# 3                   jailbirds new orleans
# 4                            kota factory
# 10    vendetta: truth, lies and the mafia
# 14        crime stories: india detectives
# ...                                   ...
# 8795                      yu-gi-oh! arc-v
# 8796                           yunus emre
# 8797                            zak storm
# 8800                   zindagi gulzar hai
# 8803                          zombie dumb
#
# [2634 rows x 1 columns]

# %% [markdown]
# # Filtrado de datos con iloc.

# %%
sub1 = merged_data.iloc[:5, [merged_data.columns.get_loc('title'), merged_data.columns.get_loc('director'), merged_data.columns.get_loc('country'),]]
sub1
# Out:
#                    title         director        country
# 0   dick johnson is dead  Kirsten Johnson  United States
# 1          blood & water              NaN   South Africa
# 2              ganglands  Julien Leclercq            NaN
# 3  jailbirds new orleans              NaN            NaN
# 4           kota factory              NaN          India

# %%
sub2 = merged_data.iloc[-5:, [merged_data.columns.get_loc('title'), merged_data.columns.get_loc('description')]]
sub2
# Out:
#             title                                        description
# 8802       zodiac  A political cartoonist, a crime reporter and a...
# 8803  zombie dumb  While living alone in a spooky town, a young g...
# 8804   zombieland  Looking to survive in a world taken over by zo...
# 8805         zoom  Dragged from civilian life, a former superhero...
# 8806       zubaan  A scrappy but poor boy worms his way into a ty...

# %%
sub3 = merged_data.iloc[:10, 1:5]
sub3
# Out:
#       type                             title                       director  \
# 0    Movie              dick johnson is dead                Kirsten Johnson
# 1  TV Show                     blood & water                            NaN
# 2  TV Show                         ganglands                Julien Leclercq
# 3  TV Show             jailbirds new orleans                            NaN
# 4  TV Show                      kota factory                            NaN
# 5  TV Show                     midnight mass                  Mike Flanagan
# 6    Movie  my little pony: a new generation  Robert Cullen, José Luis Ucha
# 7    Movie                           sankofa                   Haile Gerima
# 8  TV Show     the great british baking show                Andy Devonshire
# 9    Movie                      the starling                 Theodore Melfi
#
#                                                 cast
# 0                                                NaN
# ...

# %%
sub4 = merged_data.iloc[-7:, [merged_data.columns.get_loc('title'), merged_data.columns.get_loc('director'), merged_data.columns.get_loc('country')]]
sub4
# Out:
#                    title         director                       country
# 8800  zindagi gulzar hai              NaN                      Pakistan
# 8801             zinzana  Majid Al Ansari  United Arab Emirates, Jordan
# 8802              zodiac    David Fincher                 United States
# 8803         zombie dumb              NaN                           NaN
# 8804          zombieland  Ruben Fleischer                 United States
# 8805                zoom     Peter Hewitt                 United States
# 8806              zubaan      Mozez Singh                         India

# %%
sub5 = merged_data.iloc[15:26, :4]
sub5
# Out:
#    show_id     type                                              title  \
# 15     s16  TV Show                                  dear white people
# 16     s17    Movie  europe's most dangerous man: otto skorzeny in ...
# 17     s18  TV Show                                    falsa identidad
# 18     s19    Movie                                          intrusion
# 19     s20  TV Show                                             jaguar
# 20     s21  TV Show    monsters inside: the 24 faces of billy milligan
# 21     s22  TV Show                             resurrection: ertugrul
# 22     s23    Movie                                    avvai shanmughi
# 23     s24    Movie       go! go! cory carson: chrissy takes the wheel
# 24     s25    Movie                                              jeans
# 25     s26  TV Show                               love on the spectrum
#
#                                          director
# 15                                            NaN
# ...

# %%
sub6 = merged_data.iloc[20:31, [merged_data.columns.get_loc('title'), merged_data.columns.get_loc('release_year'), merged_data.columns.get_loc('rating')]]
sub6
# Out:
#                                               title  release_year rating
# 20  monsters inside: the 24 faces of billy milligan          2021  TV-14
# 21                           resurrection: ertugrul          2018  TV-14
# 22                                  avvai shanmughi          1996  TV-PG
# 23     go! go! cory carson: chrissy takes the wheel          2021   TV-Y
# 24                                            jeans          1998  TV-14
# 25                             love on the spectrum          2021  TV-14
# 26                                   minsara kanavu          1997  TV-PG
# 27                                        grown ups          2010  PG-13
# 28                                       dark skies          2013  PG-13
# 29                                         paranoia          2013  PG-13
# 30                                  ankahi kahaniya          2021  TV-14
